# %%
# !pip install biopython
from Bio.Seq import Seq

# DNA sequence
dna_sequence = "..."

# kmer size
k = 3

# converting the sequence to a "Biopython Seq" object
seq = Seq(dna_sequence)

# finding all kmers in the sequence
divided_sequences = [str(seq[i:i+k]) for i in range(len(seq) - k + 1)]

print("All k-mers:", " ".join(divided_sequences))

# counting unique k-mers
unique_kmers = set(divided_sequences)

# unique k-mers and their occurrences
print("\nUnique k-mers and their occurrences:")
for kmer in sorted(unique_kmers):
    print(f"{kmer}: {divided_sequences.count(kmer)} occurrences")

# total count of unique k-mers
print("\nTotal unique k-mers:", len(unique_kmers))
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 13.7 MB/s eta 0:00:00
# ...
